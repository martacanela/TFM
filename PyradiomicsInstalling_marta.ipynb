# %%
conda create -n TFM_marta3 python=3.4
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (C:\Users\pcbox\anaconda3\Lib\site-packages\conda\plugins\types.py))
# Error while loading conda entry point: anaconda-cloud-auth (cannot import name 'ChannelAuthBase' from 'conda.plugins.types' (C:\Users\pcbox\anaconda3\Lib\site-packages\conda\plugins\types.py))
#
# ...
# Examining @/win-64::__win==0=0:  67%|██████▋   | 2/3 [00:00<00:00, 20.33it/s]
#
#
# Determining conflicts:   0%|          | 0/3 [00:00<?, ?it/s]
#
#
# UnsatisfiableError:
# ...
# Solving environment: ...working... unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# ...
# Solving environment: ...working...
# Found conflicts! Looking for incompatible packages.
# This can take several minutes.  Press CTRL-C to abort.
# failed

# %%
# !pip install -U ipykernel

# %%
conda activate TFM_marta2

# %%
conda install -n TFM_marta2 ipykernel --update-deps --force-reinstall

# %%
pip install --upgrade pip

# %%
# !pip install SimpleITK
# !pip install numpy
# Out:
# ...
#      ---------------------------------------- 2.1/2.1 MB 7.9 MB/s eta 0:00:00
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
# Failed to build SimpleITK
#   error: subprocess-exited-with-error
#
#   × Building wheel for SimpleITK (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [365 lines of output]
#
#
#       --------------------------------------------------------------------------------
#       -- Trying 'Ninja (Visual Studio 17 2022 x64 v144)' generator
#       --------------------------------
#       ---------------------------
#       ----------------------
#       -----------------
#       ------------
#       -------
#       --
# ...

# %%
conda config --add channels conda-forge

# %%
conda config --show channels

# %%
# !pip install pyradiomics

# %%
conda install radiomics::pyradiomics
# Out:
# ^C
#
# Note: you may need to restart the kernel to use updated packages.
# ...
# Solving environment: ...working... unsuccessful initial attempt using frozen solve. Retrying with flexible solve.
# Solving environment: ...working... unsuccessful attempt using repodata from current_repodata.json, retrying with next repodata source.
# ...
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\Users\pcbox\anaconda3\envs\TFM_marta2
#
#   added / updated specs:
#     - radiomics::pyradiomics
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     docopt-0.6.2               |             py_1          14 KB  conda-forge
#     eigen-3.4.0                |       h91493d7_0         1.0 MB  conda-forge
#     fftw-3.3.10                |nompi_h89e6982_110         1.3 MB  conda-forge
#     intel-openmp-2024.2.1      |    h57928b3_1083         1.8 MB  conda-forge
# ...

# %%
import os
from radiomics import featureextractor

# %%
imagePath = os.path.abspath("E:/TFM Marta/Lung_radiomics_Eugeni")

# %%
from radiomics import featureextractor

# Configurar el extractor de características
params = {"binWidth": 25}
extractor = featureextractor.RadiomicsFeatureExtractor(**params)

# Calcular características radiómicas para una imagen y su ROI
result = extractor.execute(imagePath, maskPath)

# Imprimir las características calculadas
for key, value in result.items():
    print(f"{key}: {value}")
